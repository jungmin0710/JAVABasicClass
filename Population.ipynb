# %% [markdown]
# <a href="https://colab.research.google.com/github/jungmin0710/JAVABasicClass/blob/main/Population.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import csv

# %%
# %matplotlib inline  
import matplotlib as mpl  # 기본 설정 만지는 용도
import matplotlib.pyplot as plt  # 그래프 그리는 용도
import matplotlib.font_manager as fm  # 폰트 관련 용도
# !apt-get update -qq
# !apt-get install fonts-nanum* -qq
path = '/usr/share/fonts/truetype/nanum/NanumGothicEco.ttf'  # 설치된 나눔글꼴중 원하는 녀석의 전체 경로를 가져오자
font_name = fm.FontProperties(fname=path, size=10).get_name()
print(font_name)
plt.rc('font', family=font_name)
# 우선 fm._rebuild() 를 해주고
fm._rebuild()
mpl.rcParams['axes.unicode_minus'] = False#마이너스 기호 나오게
# Out:
# NanumGothic Eco

# %%
f = open('age.csv',encoding = 'cp949')
data = csv.reader(f)

result = []
name = input('인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해주세요 : ')

for row in data:
  if name in row[0]:
    for i in row[3:]:
      result.append(int(i.replace(',','')))
print(result)
# Out:
# 인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해주세요 : 사당
# ...

# %%
plt.style.use('ggplot')
plt.rc('font', family=font_name)
plt.title(name+' 지역의 인구 구조')
plt.plot(result)
plt.show()

# %%
f = open('gender.csv', encoding = 'cp949')
data = csv.reader(f)

m = []
f = []

name = input('찾고 싶은 지역의 이름을 알려주세요 : ')
for row in data:
  if name in row[0]:
    for i in row[3:104]:
      m.append(-int(i))
    for i in row[106:]:
      f.append(int(i))
    break
# Out:
# 찾고 싶은 지역의 이름을 알려주세요 : 사당

# %%
plt.style.use('ggplot')
plt.figure(figsize = (10,5), dpi = 300)
plt.rc('font', family=font_name)
plt.rcParams['axes.unicode_minus']=False
plt.title(name+' 지역의 남녀 성별 인구 분포')
plt.barh(range(101), m, label = '남성')
plt.barh(range(101), f, label = '여성')
plt.legend()
plt.show()

# %%
#제주도의 성별 인구비율 표현하기

# %%
f = open('gender.csv',  encoding = 'cp949')
data = csv.reader(f)
size = []
name = input('찾고 싶은 지역의 이름을 알려주세요 : ')

for row in data : 
  if name in row[0]:
    m = 0
    f = 0
    for i in range(101):
      m += int(row[i+3])
      f += int(row[i+106])
    break

size.append(m)
size.append(f)
print(size)
# Out:
# 찾고 싶은 지역의 이름을 알려주세요 : 제주특별자치도
# [335813, 331524]

# %%
plt.rc('font', family=font_name)
color = ['crimson','darkcyan']
plt.axis('equal')
plt.pie(size, labels = ['남','여'], autopct='%.1f%%',colors = color, startangle=90)
plt.title(name + ' 지역의 남녀 성별 비율')
plt.show()

# %%
#우리동네 인구 구조를 산점도로 나타내자

# %%
#우선 꺾은선 그래프로 나타내자
f = open('gender.csv', encoding = 'cp949')
data = csv.reader(f)
m = []
f = []

name = input('궁금한 동네를 입력해주세요 : ')
for row in data:
  if name in row[0]:
    for i in range(3, 104):
      m.append(int(row[i]))
      f.append(int(row[i+103]))
      break
# Out:
# 궁금한 동네를 입력해주세요 : 제주

# %%
plt.plot(m, label = 'Male')
plt.plot(f, label = 'Female')
plt.legend()
plt.show()

# %%
#막대그래프로 연령대별 남성 인구에서 여성인구를 뺀 값을 표현해보자
f = open('gender.csv', encoding = 'cp949')
data = csv.reader(f)
result = []
name = input('궁금한 동네를 입력해주세요 : ')

for row in data:
  if name in row[0]:
    for i in range(3, 104):
      result.append(int(row[i]) - int(row[i+103]))
    break
# Out:
# 궁금한 동네를 입력해주세요 : 제주

# %%
plt.bar(range(101),result)
plt.show()

# %%
#산점도로 표현하기

# %%
f = open('gender.csv', encoding = 'cp949')
data = csv.reader(f)
m = []
f = []

name = input('궁금한 동네를 입력해주세요 : ')
for row in data:
  if name in row[0]:
    for i in range(3, 104):
      m.append(int(row[i]))
      f.append(int(row[i+103]))
    break
# Out:
# 궁금한 동네를 입력해주세요 : 제주

# %%
plt.style.use('ggplot')
plt.rc('font', family=font_name)
plt.figure(figsize=(10,5),dpi = 300)
plt.title(name+ ' 지역의 성별 인구 그래프')
plt.scatter(m, f, c= range(101), alpha=0.5, cmap='jet')
plt.colorbar()
plt.plot(range(max(m)),range(max(m)), 'g')
plt.xlabel('남성 인구수')
plt.ylabel('여성 인구수')
plt.show()
